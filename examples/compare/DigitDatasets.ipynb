# %%
#! sudo pip install -e ../../..

# %%
% load_ext autoreload
% autoreload 2

import salad
from PIL import Image

# %%
from torchvision import transforms

from salad.datasets.da import DigitsLoader, RotationLoader

# Write Datasets with

"""
- Different Noise Domains
- Different Digits Domains
"""

loader = DigitsLoader('/tmp/data', ['mnist', 'usps'], batch_size = 32)
loader = RotationLoader('/tmp/data', 'mnist', batch_size = 32)
# Out:
# Extracting /tmp/data/zip.train.gz
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-dc3490510a51> in <module>()
#      11
#      12 loader = DigitsLoader('/tmp/data', ['mnist', 'usps'], batch_size = 32)
# ---> 13 loader = RotationLoader('/tmp/data', 'mnist', batch_size = 32)
#
# ~/thesis/code/domainadaptation/salad/datasets/da/digits.py in __init__(self, root, dataset_name, angles, **kwargs)
#      95         ]
#      96
# ---> 97         super().__init__(root, dataset_name, noisemodels, **kwargs)
#      98
#      99 class LowToHighGaussian():
#
# ~/thesis/code/domainadaptation/salad/datasets/da/digits.py in __init__(self, root, dataset_name, transforms, split, download, **kwargs)
#      75             data.append(DataLoader(ds, **kwargs))
#      76
# ---> 77         super().__init__(*data, **kwargs)
#      78
# ...

# %%
import torch

import matplotlib.pyplot as plt
from salad import utils

from salad.datasets.da import JointLoader
from torch.utils.data import DataLoader
# %matplotlib inline

from salad import utils

for batch in loader:
    
    for x,y in batch:
    
        im = utils.panelize(x.numpy()).squeeze()
        plt.imshow(im)
        plt.show()
        
    break

# %%
# %matplotlib inline

n_datasets = len(data.datasets)

fig, axes = plt.subplots(1,n_datasets,figsize=(n_datasets*5, 5))

for ax, (title, ds) in zip(axes, data.datasets.items()):
    
    ax.axis('off')
    
    samples = torch.stack([x for (x, y), _ in zip(ds, range(100))], dim = 0)
    
    print(samples.shape)
    
    im = utils.panelize(samples.numpy()).squeeze()
    
    ax.imshow(im)
    ax.set_title(title)
